# %% [markdown]
# # Slice and Dice Pandas DataFrames via Indexes

# %% [markdown]
# ## 1. Import libraries and dependencies

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## 2. Create a Path to the File Using Pathlib

# %%
# Use the Pathlib library to set the path to the CSV
csv_path = Path('../Resources/people_cleansed.csv')

# %% [markdown]
# ## 3. Read the CSV into a Pandas DataFrame

# %%
# Read in the CSV as a DataFrame
people_csv = pd.read_csv(csv_path)
people_csv.head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# 4  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ## 4. Index Selection with iloc

# %% [markdown]
# ### 1. Select the Second Row with iloc

# %%
# Select the second row of the DataFrame
people_csv.iloc[1]
# Out:
# Person_ID                                 2
# Last_Name                             Rupke
# First_Name                          Huntley
# Gender                                 Male
# University    Osaka University of Economics
# Occupation                  Project Manager
# Salary                                96053
# Email                   hrupke1@reuters.com
# Age                                      22
# Name: 1, dtype: object

# %% [markdown]
# ### 2. Select First 5 Rows Using Index Selection with iloc

# %%
# Select the first 5 rows of the DataFrame
people_csv.iloc[0:5]
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# 4  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ### 3. Select the Third Column Using Index Selection with iloc

# %%
# Select the third column of the DataFrame
people_csv.iloc[:,2].head()
# Out:
# 0    Keriann
# 1    Huntley
# 2     Gorden
# 3     Cullie
# 4      Ariel
# Name: First_Name, dtype: object

# %% [markdown]
# ### 4. Select the Second to Last Last Column Using Index Selection with iloc

# %%
# Select the second to last column of the DataFrame, with all rows
people_csv.iloc[:,-2].head()
# Out:
# 0    klenormand0@businessinsider.com
# 1                hrupke1@reuters.com
# 2        gdalgarnowch2@microsoft.com
# 3                 cputten3@nymag.com
# 4         astrangman4@bravesites.com
# Name: Email, dtype: object

# %% [markdown]
# ### 5. Select First Five Columns Using Index Selection with iloc

# %%
# Select the first five columns of the DataFrame, with all rows
people_csv.iloc[:, 0:5].head()
# Out:
#    Person_ID    Last_Name First_Name  Gender  \
# 0          1    Lenormand    Keriann  Female
# 1          2        Rupke    Huntley    Male
# 2          3  Dalgarnowch     Gorden    Male
# 3          4      Unnamed     Cullie    Male
# 4          5    Strangman      Ariel  Female
#
#                                           University
# 0                                  Aurora University
# 1                      Osaka University of Economics
# 2                                  Ludong University
# 3  Université des Sciences et de la Technologie d...
# 4                             Boise State University

# %% [markdown]
# ### 6. Select Specific Rows and Columns Using Index Selection with iloc

# %%
# Select the 2nd, 4th, 6th, 8th rows of the 1st, 3rd, and 5th columns.
people_csv.iloc[[1,3,5,7], [0,2,4]]
# Out:
#    Person_ID First_Name                                         University
# 1          2    Huntley                      Osaka University of Economics
# 3          4     Cullie  Université des Sciences et de la Technologie d...
# 5          6    Antonio                                 Babcock University
# 7          8    Helaina                                St. Paul University

# %% [markdown]
# ### 7. Select Ranges of Rows and Columns Using Index Selection with iloc

# %%
# Select the first 5 rows of the 2nd, 3rd, and 4th columns of the DataFrame
people_csv.iloc[0:5, 1:4]
# Out:
#      Last_Name First_Name  Gender
# 0    Lenormand    Keriann  Female
# 1        Rupke    Huntley    Male
# 2  Dalgarnowch     Gorden    Male
# 3      Unnamed     Cullie    Male
# 4    Strangman      Ariel  Female

# %% [markdown]
# ### 8. Assign Values to Specific Rows and Columns Using Index Assignment with iLoc

# %%
# Modify the 'last_name' column value of the thrid row
people_csv.iloc[2, people_csv.columns.get_loc('Last_Name')] = 'Maxwell'
people_csv.head()
# Out:
#    Person_ID  Last_Name First_Name  Gender  \
# 0          1  Lenormand    Keriann  Female
# 1          2      Rupke    Huntley    Male
# 2          3    Maxwell     Gorden    Male
# 3          4    Unnamed     Cullie    Male
# 4          5  Strangman      Ariel  Female
#
#                                           University          Occupation  \
# 0                                  Aurora University  Nurse Practicioner
# 1                      Osaka University of Economics     Project Manager
# 2                                  Ludong University  Environmental Tech
# 3  Université des Sciences et de la Technologie d...     Legal Assistant
# 4                             Boise State University     Project Manager
#
#     Salary                            Email  Age
# 0  58135.0  klenormand0@businessinsider.com   27
# 1  96053.0              hrupke1@reuters.com   22
# 2  59196.0      gdalgarnowch2@microsoft.com   40
# 3  88493.0               cputten3@nymag.com   62
# 4  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ## 5. Index Selection with `loc`:

# %% [markdown]
# ### 1. Set Column as Pandas DataFrame Index

# %%
# Set the index as the 'First_Name' column
people_csv = people_csv.set_index(people_csv['First_Name'])
people_csv.head()
# Out:
#             Person_ID  Last_Name First_Name  Gender  \
# First_Name
# Keriann             1  Lenormand    Keriann  Female
# Huntley             2      Rupke    Huntley    Male
# Gorden              3    Maxwell     Gorden    Male
# Cullie              4    Unnamed     Cullie    Male
# Ariel               5  Strangman      Ariel  Female
#
#                                                    University  \
# First_Name
# Keriann                                     Aurora University
# Huntley                         Osaka University of Economics
# Gorden                                      Ludong University
# Cullie      Université des Sciences et de la Technologie d...
# Ariel                                  Boise State University
#
#                     Occupation   Salary                            Email  Age
# First_Name
# Keriann     Nurse Practicioner  58135.0  klenormand0@businessinsider.com   27
# Huntley        Project Manager  96053.0              hrupke1@reuters.com   22
# Gorden      Environmental Tech  59196.0      gdalgarnowch2@microsoft.com   40
# Cullie         Legal Assistant  88493.0               cputten3@nymag.com   62
# Ariel          Project Manager  89073.0       astrangman4@bravesites.com   47

# %% [markdown]
# ### 2. Sort Pandas DataFrame by Index

# %%
# Sort the index in descending order
people_csv = people_csv.sort_index(ascending=False)
people_csv
# Out:
#             Person_ID      Last_Name First_Name  Gender  \
# First_Name
# Zsazsa             81        Cutajar     Zsazsa  Female
# Zerk               59       Goulston       Zerk    Male
# Zebulon            58      Josefovic    Zebulon    Male
# Zandra            816     Kollaschek     Zandra  Female
# Zachariah         825           Akid  Zachariah    Male
# ...               ...            ...        ...     ...
# Abra              177         Vawton       Abra  Female
# Abner             158  Christauffour      Abner    Male
# Abbye             125      MacKnight      Abbye  Female
# Abbot             459      McGaughey      Abbot    Male
# Aaron             461       De Brett      Aaron    Male
#
#                                                    University  \
# First_Name
# Zsazsa      Asia Pacific Institute of Information Technolo...
# Zerk                    Universidad Tecnologica de la Mixteca
# Zebulon                               Rajiv Gandhi University
# Zandra                       Western International University
# Zachariah                             Kyoto Sangyo University
# ...                                                       ...
# Abra                      Kawasaki University of Medical Care
# Abner                         Universidade Federal de Alagoas
# Abbye                               Savannah State University
# Abbot                                 University of Mauritius
# Aaron                                      Tsurumi University
#
#                               Occupation    Salary  \
# First_Name
# Zsazsa       Mechanical Systems Engineer   57814.0
# Zerk        Budget/Accounting Analyst II   71428.0
# Zebulon              Staff Accountant IV   82462.0
# Zandra          Senior Financial Analyst  109904.0
# Zachariah             Office Assistant I  111040.0
# ...                                  ...       ...
# Abra                   Financial Advisor   76598.0
# Abner         Account Representative III  102758.0
# Abbye                Account Coordinator   90949.0
# Abbot                       Food Chemist  105216.0
# Aaron                  Director of Sales   76098.0
#
#                                        Email  Age
# First_Name
# Zsazsa                     zcutajar28@i2i.jp   27
# Zerk               zgoulston1m@artisteer.com   35
# Zebulon             zjosefovic1l@pcworld.com   63
# Zandra                 zkollaschekmn@home.pl   34
# Zachariah                   zakidmw@live.com   47
# ...                                      ...  ...
# Abra                   avawton4w@nbcnews.com   23
# Abner             achristauffour4d@tmall.com   47
# Abbye       amacknight3g@theglobeandmail.com   42
# Abbot                  amcgaugheycq@jugem.jp   35
# Aaron             adebrettcs@yellowpages.com   45
#
# [973 rows x 9 columns]

# %% [markdown]
# ### 3. Select Specific Row with Index Selection using loc

# %%
# Select the row with the index 'Robert'
people_csv.loc['Robert']
# Out:
#             Person_ID  Last_Name First_Name Gender  \
# First_Name
# Robert            656  McMenamin     Robert   Male
# Robert            724   Giraudat     Robert   Male
#
#                                           University           Occupation  \
# First_Name
# Robert                            Hanshin University  Marketing Assistant
# Robert      Universidad Nacional del Centro del Perú    Web Developer III
#
#               Salary                          Email  Age
# First_Name
# Robert      116802.0  rmcmenamini7@odnoklassniki.ru   40
# Robert       78184.0             rgiraudatk3@ed.gov   28

# %% [markdown]
# ### 4. Select Rows with Conditionals using loc

# %%
# Select the rows where `Gender` is equal to 'Female' using `loc`.
people_csv.loc[people_csv['Gender'] == 'Female'].head()
# Out:
#             Person_ID   Last_Name First_Name  Gender  \
# First_Name
# Zsazsa             81     Cutajar     Zsazsa  Female
# Zandra            816  Kollaschek     Zandra  Female
# Yovonnda          178     Trustie   Yovonnda  Female
# Winni             715     Fishley      Winni  Female
# Winna             260     Magowan      Winna  Female
#
#                                                    University  \
# First_Name
# Zsazsa      Asia Pacific Institute of Information Technolo...
# Zandra                       Western International University
# Yovonnda                     Universidad Autónoma de Campeche
# Winni       State University of New York College of Techno...
# Winna                         Maritime University in Szczecin
#
#                              Occupation    Salary                       Email  \
# First_Name
# Zsazsa      Mechanical Systems Engineer   57814.0           zcutajar28@i2i.jp
# Zandra         Senior Financial Analyst  109904.0       zkollaschekmn@home.pl
# Yovonnda              Assistant Manager   69877.0          ytrustie4x@mlb.com
# Winni               Executive Secretary   98451.0      wfishleyju@harvard.edu
# Winna               Structural Engineer   61486.0  wmagowan77@studiopress.com
#
#             Age
# First_Name
# Zsazsa       27
# Zandra       34
# Yovonnda     59
# Winni        40
# Winna        35

# %% [markdown]
# ### 5. Assign Values to Specific Rows and Columns Using Index Assignment with loc

# %%
# Change the `First_Name` value of the rows with 'Zerk' as the `First_Name` index to 'AA-Ron'
people_csv.loc['Zerk', 'First_Name'] = 'AA-Ron'
people_csv.head()
# Out:
#             Person_ID   Last_Name First_Name  Gender  \
# First_Name
# Zsazsa             81     Cutajar     Zsazsa  Female
# Zerk               59    Goulston     AA-Ron    Male
# Zebulon            58   Josefovic    Zebulon    Male
# Zandra            816  Kollaschek     Zandra  Female
# Zachariah         825        Akid  Zachariah    Male
#
#                                                    University  \
# First_Name
# Zsazsa      Asia Pacific Institute of Information Technolo...
# Zerk                    Universidad Tecnologica de la Mixteca
# Zebulon                               Rajiv Gandhi University
# Zandra                       Western International University
# Zachariah                             Kyoto Sangyo University
#
#                               Occupation    Salary                      Email  \
# First_Name
# Zsazsa       Mechanical Systems Engineer   57814.0          zcutajar28@i2i.jp
# Zerk        Budget/Accounting Analyst II   71428.0  zgoulston1m@artisteer.com
# Zebulon              Staff Accountant IV   82462.0   zjosefovic1l@pcworld.com
# Zandra          Senior Financial Analyst  109904.0      zkollaschekmn@home.pl
# Zachariah             Office Assistant I  111040.0           zakidmw@live.com
#
#             Age first_name
# First_Name
# Zsazsa       27        NaN
# Zerk         35        NaN
# Zebulon      63        NaN
# Zandra       34        NaN
# Zachariah    47        NaN
